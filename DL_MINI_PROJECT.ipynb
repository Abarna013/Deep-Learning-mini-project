# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin

# Set the search query for apple seeds
search_query = "Single MRI image duchenne muscular dystrophy"

# Set the number of images to download
num_images = 100

# Set the directory to save the downloaded images
save_directory = "/content/drive/MyDrive/Neuro/dhdgen"

# Create the directory if it doesn't exist
os.makedirs(save_directory, exist_ok=True)

# Prepare the search URL
search_url = f"https://www.google.com/search?q={search_query}&tbm=isch"

# Send a GET request to the search URL
response = requests.get(search_url)

# Parse the response content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all image elements in the parsed HTML
image_elements = soup.find_all('img')

# Download the images
downloaded_images = 0
for i, img in enumerate(image_elements):
    # Get the image source URL
    img_url = img['src']

    try:
        # Check if the URL is a relative URL
        if img_url.startswith('/'):
            # Construct the absolute URL using the base URL of the search page
            img_url = urljoin(search_url, img_url)

        # Send a GET request to download the image
        img_response = requests.get(img_url, stream=True)
        img_response.raise_for_status()
        content_type = img_response.headers.get('Content-Type')
        if content_type == 'image/jpeg':
            file_extension = 'jpg'
        elif content_type == 'image/png':
            file_extension = 'png'
        else:
            continue
        # Save the image to the specified directory
        with open(os.path.join(save_directory, f"image{i+1}.jpg"), 'wb') as f:
            for chunk in img_response.iter_content(chunk_size=128):
                f.write(chunk)

        downloaded_images += 1

        if downloaded_images >= num_images:
            break

    except requests.exceptions.HTTPError:
        continue

# Print the number of downloaded images
print("Number of downloaded images:", downloaded_images)
# Out:
# Number of downloaded images: 20

# %%
import os
from sklearn.model_selection import train_test_split

# Define the path to your image dataset directory
dataset_dir = '/content/drive/MyDrive/Neuro/dhdgen'

# List all image file names in the dataset directory
image_files = [file for file in os.listdir(dataset_dir) if file.endswith('.jpg')]  # Adjust the extension if needed

# Split the dataset into training and testing sets
train_files, test_files = train_test_split(image_files, test_size=0.2, random_state=42)

# Define directories for train and test sets
train_dir = '/content/drive/MyDrive/Neuro/dhdgen/test'
test_dir = '/content/drive/MyDrive/Neuro/dhdgen/train'

# Create directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Move files to train and test directories
for file in train_files:
    src_path = os.path.join(dataset_dir, file)
    dst_path = os.path.join(train_dir, file)
    os.rename(src_path, dst_path)

for file in test_files:
    src_path = os.path.join(dataset_dir, file)
    dst_path = os.path.join(test_dir, file)
    os.rename(src_path, dst_path)

print(f"Number of images in train set: {len(train_files)}")
print(f"Number of images in test set: {len(test_files)}")
# Out:
# Number of images in train set: 16
# Number of images in test set: 4

# %%
# Multi-Layer Perceptron (MLP)






from google.colab import drive
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import os
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Define main data directory
neuro_dir = '/content/drive/MyDrive/Neuro'

# Create an MLP model
model = Sequential([
    Flatten(input_shape=(224, 224, 3)),
    Dense(128, activation='relu'),
    Dropout(0.5),  # This line had an indentation issue in your previous message
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# List all main subfolders
main_subfolders = ['dhdleg', 'dhdhead', 'dhdgen', 'dhdpelvic', 'llg']

# Initialize counters for high severe and less severe images
high_severe_count = 0
less_severe_count = 0

# Lists to store true labels and predicted probabilities for evaluation
true_labels = []
predicted_probs = []

# Loop through main subfolders
for main_subfolder in main_subfolders:
    main_data_dir = os.path.join(neuro_dir, main_subfolder)

    subsubfolders = ['train', 'test']

    for subsubfolder in subsubfolders:
        data_dir = os.path.join(main_data_dir, subsubfolder)

        print(f"Processing subsubfolder: {main_subfolder}/{subsubfolder}")

        # List all image filenames in the subfolder
        image_filenames = [filename for filename in os.listdir(data_dir) if filename.lower().endswith(('.jpg', '.jpeg'))]

        if not image_filenames:
            print("No images found in the directory.")
            continue

        for image_filename in image_filenames:
            # Load the image, preprocess it, and make a prediction
            image_path = os.path.join(data_dir, image_filename)
            img = load_img(image_path, target_size=(224, 224))
            img_array = img_to_array(img)
            img_array = img_array / 255.0  # Normalize pixel values

            true_label = 1  # Assuming all are high severe
            true_labels.append(true_label)

            prediction = model.predict(np.expand_dims(img_array, axis=0))
            predicted_prob = prediction[0][0]
            predicted_probs.append(predicted_prob)

            if predicted_prob <= 0.40:
                less_severe_count += 1
            else:
                high_severe_count += 1

            severity = "less severe" if predicted_prob <= 0.70 else "high severe"

            print(f"Image: {image_filename} - Predicted Accuracy: {predicted_prob:.4f} - Severity: {severity}")

# Calculate overall accuracies
total_images = high_severe_count + less_severe_count
high_severe_accuracy = (high_severe_count / total_images) * 100 if total_images > 0 else 0
less_severe_accuracy = (less_severe_count / total_images) * 100 if total_images > 0 else 0

print(f"\nOverall High Severe Accuracy: {high_severe_accuracy:.2f}%")
print(f"Overall Less Severe Accuracy: {less_severe_accuracy:.2f}%")

# Evaluate the model using true labels and predicted probabilities
y_true = np.array(true_labels)
y_pred = np.array(predicted_probs) <= 0.40
print("\nClassification Report:")
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing subsubfolder: dhdleg/train
# 1/1 [==============================] - 0s 72ms/step
# Image: image5.jpg - Predicted Accuracy: 0.3858 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image21.jpg - Predicted Accuracy: 0.4667 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image16.jpg - Predicted Accuracy: 0.4380 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image8.jpg - Predicted Accuracy: 0.3931 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image13.jpg - Predicted Accuracy: 0.5086 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image10.jpg - Predicted Accuracy: 0.4472 - Severity: less severe
# 1/1 [==============================] - 0s 32ms/step
# Image: image7.jpg - Predicted Accuracy: 0.4680 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image11.jpg - Predicted Accuracy: 0.4706 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3989 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image15.jpg - Predicted Accuracy: 0.5885 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image20.jpg - Predicted Accuracy: 0.3322 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image18.jpg - Predicted Accuracy: 0.3481 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image14.jpg - Predicted Accuracy: 0.3999 - Severity: less severe
# 1/1 [==============================] - 0s 31ms/step
# Image: image12.jpg - Predicted Accuracy: 0.4848 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4138 - Severity: less severe
# 1/1 [==============================] - 0s 33ms/step
# Image: image9.jpg - Predicted Accuracy: 0.4193 - Severity: less severe
# Processing subsubfolder: dhdleg/test
# 1/1 [==============================] - 0s 27ms/step
# Image: image3.jpg - Predicted Accuracy: 0.4886 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image17.jpg - Predicted Accuracy: 0.4841 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image2.jpg - Predicted Accuracy: 0.4485 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image19.jpg - Predicted Accuracy: 0.3973 - Severity: less severe
# Processing subsubfolder: dhdhead/train
# 1/1 [==============================] - 0s 27ms/step
# Image: image20.jpg - Predicted Accuracy: 0.4841 - Severity: less severe
# 1/1 [==============================] - 0s 25ms/step
# Image: image21.jpg - Predicted Accuracy: 0.4680 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image8.jpg - Predicted Accuracy: 0.3435 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image13.jpg - Predicted Accuracy: 0.4472 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4309 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image7.jpg - Predicted Accuracy: 0.3870 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image16.jpg - Predicted Accuracy: 0.5169 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image12.jpg - Predicted Accuracy: 0.4193 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image6.jpg - Predicted Accuracy: 0.5411 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image9.jpg - Predicted Accuracy: 0.4887 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image4.jpg - Predicted Accuracy: 0.4667 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image11.jpg - Predicted Accuracy: 0.4491 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image10.jpg - Predicted Accuracy: 0.4485 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image14.jpg - Predicted Accuracy: 0.5086 - Severity: less severe
# 1/1 [==============================] - 0s 30ms/step
# Image: image5.jpg - Predicted Accuracy: 0.4913 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image15.jpg - Predicted Accuracy: 0.4811 - Severity: less severe
# Processing subsubfolder: dhdhead/test
# 1/1 [==============================] - 0s 27ms/step
# Image: image19.jpg - Predicted Accuracy: 0.4848 - Severity: less severe
# 1/1 [==============================] - 0s 32ms/step
# Image: image2.jpg - Predicted Accuracy: 0.3781 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image17.jpg - Predicted Accuracy: 0.4315 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image3.jpg - Predicted Accuracy: 0.3211 - Severity: less severe
# Processing subsubfolder: dhdgen/train
# 1/1 [==============================] - 0s 31ms/step
# Image: image2.jpg - Predicted Accuracy: 0.3522 - Severity: less severe
# 1/1 [==============================] - 0s 30ms/step
# Image: image3.jpg - Predicted Accuracy: 0.4472 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image17.jpg - Predicted Accuracy: 0.3486 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image19.jpg - Predicted Accuracy: 0.4491 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image12.jpg - Predicted Accuracy: 0.4335 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image15.jpg - Predicted Accuracy: 0.3709 - Severity: less severe
# 1/1 [==============================] - 0s 30ms/step
# Image: image8.jpg - Predicted Accuracy: 0.4485 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4680 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image16.jpg - Predicted Accuracy: 0.4026 - Severity: less severe
# 1/1 [==============================] - 0s 35ms/step
# Image: image21.jpg - Predicted Accuracy: 0.4193 - Severity: less severe
# 1/1 [==============================] - 0s 32ms/step
# Image: image11.jpg - Predicted Accuracy: 0.3931 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image10.jpg - Predicted Accuracy: 0.3858 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image20.jpg - Predicted Accuracy: 0.3844 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image5.jpg - Predicted Accuracy: 0.4315 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image7.jpg - Predicted Accuracy: 0.4879 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image14.jpg - Predicted Accuracy: 0.3486 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3665 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image9.jpg - Predicted Accuracy: 0.4634 - Severity: less severe
# 1/1 [==============================] - 0s 30ms/step
# Image: image6.jpg - Predicted Accuracy: 0.3522 - Severity: less severe
# 1/1 [==============================] - 0s 33ms/step
# Image: image13.jpg - Predicted Accuracy: 0.
ms/step
# Image: image18.jpg - Predicted Accuracy: 0.3475 - Severity: less severe
# 1/1 [==============================] - 0s 31ms/step
# Image: image9.jpg - Predicted Accuracy: 0.4485 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image16.jpg - Predicted Accuracy: 0.4460 - Severity: less severe
# 1/1 [==============================] - 0s 29ms/step
# Image: image13.jpg - Predicted Accuracy: 0.3430 - Severity: less severe
# Processing subsubfolder: llg/test
# 1/1 [==============================] - 0s 28ms/step
# Image: image19.jpg - Predicted Accuracy: 0.3020 - Severity: less severe
# 1/1 [==============================] - 0s 28ms/step
# Image: image2.jpg - Predicted Accuracy: 0.4388 - Severity: less severe
# 1/1 [==============================] - 0s 27ms/step
# Image: image17.jpg - Predicted Accuracy: 0.4219 - Severity: less severe
# 1/1 [==============================] - 0s 26ms/step
# Image: image3.jpg - Predicted Accuracy: 0.5083 - Severity: less severe
#
# Overall High Severe Accuracy: 67.50%
# Overall Less Severe Accuracy: 32.50%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.33      0.49       120
#
#     accuracy                           0.33       120
#    macro avg       0.50      0.16      0.25       120
# weighted avg       1.00      0.33      0.49       120

# %%
# rnn




from google.colab import drive
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, SimpleRNN, Dropout, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import os
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Define main data directory
neuro_dir = '/content/drive/MyDrive/Neuro'

# Load pre-trained InceptionV3 model without top layers
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)

# Reshape for RNN
rnn_input = Reshape((1, 128))(x)  # Reshape to (timesteps, features)

# Add RNN layer
rnn_layer = SimpleRNN(64)(rnn_input)

predictions_layer = Dense(1, activation='sigmoid')(rnn_layer)
model = Model(inputs=base_model.input, outputs=predictions_layer)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# List all main subfolders
main_subfolders = ['dhdleg', 'dhdhead', 'dhdgen', 'dhdpelvic','llg']

# Initialize counters for high severe and less severe images
high_severe_count = 0
less_severe_count = 0

# Lists to store true labels and predicted probabilities for evaluation
true_labels = []
predicted_probs = []

# Loop through main subfolders
for main_subfolder in main_subfolders:
    main_data_dir = os.path.join(neuro_dir, main_subfolder)

    subsubfolders = ['train', 'test']

    for subsubfolder in subsubfolders:
        data_dir = os.path.join(main_data_dir, subsubfolder)

        print(f"Processing subsubfolder: {main_subfolder}/{subsubfolder}")

        # List all image filenames in the subfolder
        image_filenames = [filename for filename in os.listdir(data_dir) if filename.lower().endswith(('.jpg', '.jpeg'))]

        if not image_filenames:
            print("No images found in the directory.")
            continue

        for image_filename in image_filenames:
            # Load the image, preprocess it, and make a prediction
            image_path = os.path.join(data_dir, image_filename)
            img = load_img(image_path, target_size=(224, 224))
            img_array = img_to_array(img)
            img_array = img_array / 255.0  # Normalize pixel values
            img_array = img_array.reshape((1,) + img_array.shape)

            true_label = 1  # Assuming all are high severe
            true_labels.append(true_label)

            prediction = model.predict(img_array)
            predicted_prob = prediction[0][0]
            predicted_probs.append(predicted_prob)

            if predicted_prob <= 0.40:
                less_severe_count += 1
            else:
                high_severe_count += 1

            severity = "less severe" if predicted_prob <= 0.40 else "high severe"

            print(f"Image: {image_filename} - Predicted Accuracy: {predicted_prob:.4f} - Severity: {severity}")

# Calculate overall accuracies
total_images = high_severe_count + less_severe_count
high_severe_accuracy = (high_severe_count / total_images) * 100 if total_images > 0 else 0
less_severe_accuracy = (less_severe_count / total_images) * 100 if total_images > 0 else 0

print(f"\nOverall High Severe Accuracy: {high_severe_accuracy:.2f}%")
print(f"Overall Less Severe Accuracy: {less_severe_accuracy:.2f}%")

# Evaluate the model using true labels and predicted probabilities
y_true = np.array(true_labels)
y_pred = np.array(predicted_probs) <= 0.40
print("\nClassification Report:")
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing subsubfolder: dhdleg/train
# 1/1 [==============================] - 3s 3s/step
# Image: image5.jpg - Predicted Accuracy: 0.1564 - Severity: less severe
# 1/1 [==============================] - 0s 254ms/step
# Image: image21.jpg - Predicted Accuracy: 0.1500 - Severity: less severe
# 1/1 [==============================] - 0s 226ms/step
# Image: image16.jpg - Predicted Accuracy: 0.2332 - Severity: less severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image8.jpg - Predicted Accuracy: 0.2859 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image13.jpg - Predicted Accuracy: 0.4187 - Severity: high severe
# 1/1 [==============================] - 0s 142ms/step
# Image: image10.jpg - Predicted Accuracy: 0.1863 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image7.jpg - Predicted Accuracy: 0.5660 - Severity: high severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image11.jpg - Predicted Accuracy: 0.1435 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image4.jpg - Predicted Accuracy: 0.1951 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image15.jpg - Predicted Accuracy: 0.2409 - Severity: less severe
# 1/1 [==============================] - 0s 157ms/step
# Image: image20.jpg - Predicted Accuracy: 0.2398 - Severity: less severe
# 1/1 [==============================] - 0s 145ms/step
# Image: image18.jpg - Predicted Accuracy: 0.2921 - Severity: less severe
# 1/1 [==============================] - 0s 140ms/step
# Image: image14.jpg - Predicted Accuracy: 0.1418 - Severity: less severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image12.jpg - Predicted Accuracy: 0.2906 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image6.jpg - Predicted Accuracy: 0.5270 - Severity: high severe
# 1/1 [==============================] - 0s 146ms/step
# Image: image9.jpg - Predicted Accuracy: 0.4678 - Severity: high severe
# Processing subsubfolder: dhdleg/test
# 1/1 [==============================] - 0s 134ms/step
# Image: image3.jpg - Predicted Accuracy: 0.2921 - Severity: less severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image17.jpg - Predicted Accuracy: 0.4169 - Severity: high severe
# 1/1 [==============================] - 0s 137ms/step
# Image: image2.jpg - Predicted Accuracy: 0.2837 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image19.jpg - Predicted Accuracy: 0.2557 - Severity: less severe
# Processing subsubfolder: dhdhead/train
# 1/1 [==============================] - 0s 140ms/step
# Image: image20.jpg - Predicted Accuracy: 0.4169 - Severity: high severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image21.jpg - Predicted Accuracy: 0.5660 - Severity: high severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image8.jpg - Predicted Accuracy: 0.2820 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image13.jpg - Predicted Accuracy: 0.1863 - Severity: less severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4860 - Severity: high severe
# 1/1 [==============================] - 0s 142ms/step
# Image: image7.jpg - Predicted Accuracy: 0.1887 - Severity: less severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image16.jpg - Predicted Accuracy: 0.2063 - Severity: less severe
# 1/1 [==============================] - 0s 123ms/step
# Image: image12.jpg - Predicted Accuracy: 0.4678 - Severity: high severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image6.jpg - Predicted Accuracy: 0.2982 - Severity: less severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image9.jpg - Predicted Accuracy: 0.3314 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image4.jpg - Predicted Accuracy: 0.1500 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image11.jpg - Predicted Accuracy: 0.2644 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image10.jpg - Predicted Accuracy: 0.2837 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image14.jpg - Predicted Accuracy: 0.4187 - Severity: high severe
# 1/1 [==============================] - 0s 126ms/step
# Image: image5.jpg - Predicted Accuracy: 0.3227 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image15.jpg - Predicted Accuracy: 0.4360 - Severity: high severe
# Processing subsubfolder: dhdhead/test
# 1/1 [==============================] - 0s 139ms/step
# Image: image19.jpg - Predicted Accuracy: 0.2906 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image2.jpg - Predicted Accuracy: 0.2769 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image17.jpg - Predicted Accuracy: 0.3335 - Severity: less severe
# 1/1 [==============================] - 0s 136ms/step
# Image: image3.jpg - Predicted Accuracy: 0.2962 - Severity: less severe
# Processing subsubfolder: dhdgen/train
# 1/1 [==============================] - 0s 134ms/step
# Image: image2.jpg - Predicted Accuracy: 0.4415 - Severity: high severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image3.jpg - Predicted Accuracy: 0.1863 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image17.jpg - Predicted Accuracy: 0.4173 - Severity: high severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image19.jpg - Predicted Accuracy: 0.2644 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image12.jpg - Predicted Accuracy: 0.5942 - Severity: high severe
# 1/1 [==============================] - 0s 144ms/step
# Image: image15.jpg - Predicted Accuracy: 0.5441 - Severity: high severe
# 1/1 [==============================] - 0s 144ms/step
# Image: image8.jpg - Predicted Accuracy: 0.2837 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image18.jpg - Predicted Accuracy: 0.5660 - Severity: high severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image16.jpg - Predicted Accuracy: 0.1591 - Severity: less severe
# 1/1 [==============================] - 0s 148ms/step
# Image: image21.jpg - Predicted Accuracy: 0.4678 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image11.jpg - Predicted Accuracy: 0.2859 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image10.jpg - Predicted Accuracy: 0.1564 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image20.jpg - Predicted Accuracy: 0.1802 - Severity: less severe
# 1/1 [==============================] - 0s 229ms/step
# Image: image5.jpg - Predicted Accuracy: 0.3335 - Severity: less severe
# 1/1 [==============================] - 0s 260ms/step
# Image: image7.jpg - Predicted Accuracy: 0.1944 - Severity: less severe
# 1/1 [==============================] - 0s 238ms/step
# Image: image14.jpg - Predicted Accuracy: 0.4173 - Severity: high severe
# 1/1 [==============================] - 0s 240ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3055 - Severity: less severe
# 1/1 [==============================] - 0s 248ms/step
# Image: image9.jpg - Predicted Accuracy: 0.4564 - Severity: high severe
# 1/1 [==============================] - 0s 231ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4415 - Severity: high severe
# 1/1 [==============================] - 0s 238ms/step
# Image: image13.jpg - Predicted Accuracy: 0.2476 - Severity: less severe
# Processing subsubfolder: dhdgen/test
# 1/1 [==============================] - 0s 236ms/step
# Image: image4.jpg - Predicted Accuracy: 0.1944 - Severity: less severe
# 1/1 [==============================] - 0s 229ms/step
# Image: image5.jpg - Predicted Accuracy: 0.1951 - Severity: less severe
# 1/1 [==============================] - 0s 228ms/step
# Image: image6.jpg - Predicted Accuracy: 0.3055 - Severity: less severe
# 1/1 [==============================] - 0s 240ms/step
# Image: image7.jpg - Predicted Accuracy: 0.3335 - Severity: less severe
# 1/1 [==============================] - 0s 221ms/step
# Image: image8.jpg - Predicted Accuracy: 0.2837 - Severity: less severe
# 1/1 [==============================] - 0s 223ms/step
# Image: image9.jpg - Predicted Accuracy: 0.2859 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image10.jpg - Predicted Accuracy: 0.1591 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image11.jpg - Predicted Accuracy: 0.4865 - Severity: high severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image12.jpg - Predicted Accuracy: 0.7424 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image13.jpg - Predicted Accuracy: 0.5441 - Severity: high severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image14.jpg - Predicted Accuracy: 0.5942 - Severity: high severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image15.jpg - Predicted Accuracy: 0.1564 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image16.jpg - Predicted Accuracy: 0.2476 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image18.jpg - Predicted Accuracy: 0.6107 - Severity: high severe
# 1/1 [==============================] - 0s 142ms/step
# Image: image20.jpg - Predicted Accuracy: 0.1802 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image21.jpg - Predicted Accuracy: 0.3949 - Severity: less severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image3.jpg - Predicted Accuracy: 0.1951 - Severity: less severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image2.jpg - Predicted Accuracy: 0.1863 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image17.jpg - Predicted Accuracy: 0.2644 - Severity: less severe
# 1/1 [==============================] - 0s 143ms/step
# Image: image19.jpg - Predicted Accuracy: 0.3949 - Severity: less severe
# Processing subsubfolder: dhdpelvic/train
# 1/1 [==============================] - 0s 138ms/step
# Image: image7.jpg - Predicted Accuracy: 0.4173 - Severity: high severe
# 1/1 [==============================] - 0s 137ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4415 - Severity: high severe
# 1/1 [==============================] - 0s 140ms/step
# Image: image21.jpg - Predicted Accuracy: 0.2332 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image16.jpg - Predicted Accuracy: 0.4360 - Severity: high severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image10.jpg - Predicted Accuracy: 0.2644 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image18.jpg - Predicted Accuracy: 0.1564 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image8.jpg - Predicted Accuracy: 0.5942 - Severity: high severe
# 1/1 [==============================] - 0s 137ms/step
# Image: image5.jpg - Predicted Accuracy: 0.1887 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image14.jpg - Predicted Accuracy: 0.4826 - Severity: high severe
# 1/1 [==============================] - 0s 123ms/step
# Image: image4.jpg - Predicted Accuracy: 0.1863 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image11.jpg - Predicted Accuracy: 0.1500 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image9.jpg - Predicted Accuracy: 0.3653 - Severity: less severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image13.jpg - Predicted Accuracy: 0.2829 - Severity: less severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image12.jpg - Predicted Accuracy: 0.4678 - Severity: high severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image20.jpg - Predicted Accuracy: 0.1944 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image15.jpg - Predicted Accuracy: 0.1435 - Severity: less severe
# Processing subsubfolder: dhdpelvic/test
# 1/1 [==============================] - 0s 130ms/step
# Image: image19.jpg - Predicted Accuracy: 0.2748 - Severity: less severe
# 1/1 [==============================] - 0s 126ms/step
# Image: image17.jpg - Predicted Accuracy: 0.2094 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image2.jpg - Predicted Accuracy: 0.2837 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image3.jpg - Predicted Accuracy: 0.4169 - Severity: high severe
# Processing subsubfolder: llg/train
# 1/1 [==============================] - 0s 133ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3949 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image21.jpg - Predicted Accuracy: 0.3207 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image14.jpg - Predicted Accuracy: 0.5159 - Severity: high severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image15.jpg - Predicted Accuracy: 0.1186 - Severity: less severe
# 1/1 [==============================] - 0s 136ms/step
# Image: image11.jpg - Predicted Accuracy: 0.4968 - Severity: high severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image5.jpg - Predicted Accuracy: 0.5291 - Severity: high severe
# 1/1 [==============================] - 0s 136ms/step
# Image: image10.jpg - Predicted Accuracy: 0.4824 - Severity: high severe
# 1/1 [==============================] - 0s 146ms/step
# Image: image7.jpg - Predicted Accuracy: 0.1435 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image6.jpg - Predicted Accuracy: 0.1945 - Severity: less severe
# 1/1 [==============================] - 0s 143ms/step
# Image: image12.jpg - Predicted Accuracy: 0.3998 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image8.jpg - Predicted Accuracy: 0.1622 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image20.jpg - Predicted Accuracy: 0.3618 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4224 - Severity: high severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image9.jpg - Predicted Accuracy: 0.2837 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image16.jpg - Predicted Accuracy: 0.2563 - Severity: less severe
# 1/1 [==============================] - 0s 224ms/step
# Image: image13.jpg - Predicted Accuracy: 0.1308 - Severity: less severe
# Processing subsubfolder: llg/test
# 1/1 [==============================] - 0s 233ms/step
# Image: image19.jpg - Predicted Accuracy: 0.2522 - Severity: less severe
# 1/1 [==============================] - 0s 235ms/step
# Image: image2.jpg - Predicted Accuracy: 0.1911 - Severity: less severe
# 1/1 [==============================] - 0s 232ms/step
# Image: image17.jpg - Predicted Accuracy: 0.2910 - Severity: less severe
# 1/1 [==============================] - 0s 230ms/step
# Image: image3.jpg - Predicted Accuracy: 0.3151 - Severity: less severe
#
# Overall High Severe Accuracy: 30.83%
# Overall Less Severe Accuracy: 69.17%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.69      0.82       120
#
#     accuracy                           0.69       120
#    macro avg       0.50      0.35      0.41       120
# weighted avg       1.00      0.69      0.82       120

# %%
# cnn




from google.colab import drive
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, SimpleRNN, Dropout, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import os
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Define main data directory
neuro_dir = '/content/drive/MyDrive/Neuro'

# Load pre-trained InceptionV3 model without top layers
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)

# Reshape for RNN
rnn_input = Reshape((1, 128))(x)  # Reshape to (timesteps, features)

# Add RNN layer
rnn_layer = SimpleRNN(64)(rnn_input)

predictions_layer = Dense(1, activation='sigmoid')(rnn_layer)
model = Model(inputs=base_model.input, outputs=predictions_layer)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# List all main subfolders
main_subfolders = ['dhdleg', 'dhdhead', 'dhdgen', 'dhdpelvic','llg']

# Initialize counters for high severe and less severe images
high_severe_count = 0
less_severe_count = 0

# Lists to store true labels and predicted probabilities for evaluation
true_labels = []
predicted_probs = []

# Loop through main subfolders
for main_subfolder in main_subfolders:
    main_data_dir = os.path.join(neuro_dir, main_subfolder)

    subsubfolders = ['train', 'test']

    for subsubfolder in subsubfolders:
        data_dir = os.path.join(main_data_dir, subsubfolder)

        print(f"Processing subsubfolder: {main_subfolder}/{subsubfolder}")

        # List all image filenames in the subfolder
        image_filenames = [filename for filename in os.listdir(data_dir) if filename.lower().endswith(('.jpg', '.jpeg'))]

        if not image_filenames:
            print("No images found in the directory.")
            continue

        for image_filename in image_filenames:
            # Load the image, preprocess it, and make a prediction
            image_path = os.path.join(data_dir, image_filename)
            img = load_img(image_path, target_size=(224, 224))
            img_array = img_to_array(img)
            img_array = img_array / 255.0  # Normalize pixel values
            img_array = img_array.reshape((1,) + img_array.shape)

            true_label = 1  # Assuming all are high severe
            true_labels.append(true_label)

            prediction = model.predict(img_array)
            predicted_prob = prediction[0][0]
            predicted_probs.append(predicted_prob)

            if predicted_prob <= 0.60:
                less_severe_count += 1
            else:
                high_severe_count += 1

            severity = "less severe" if predicted_prob <= 0.60 else "high severe"

            print(f"Image: {image_filename} - Predicted Accuracy: {predicted_prob:.4f} - Severity: {severity}")

# Calculate overall accuracies
total_images = high_severe_count + less_severe_count
high_severe_accuracy = (high_severe_count / total_images) * 100 if total_images > 0 else 0
less_severe_accuracy = (less_severe_count / total_images) * 100 if total_images > 0 else 0

print(f"\nOverall High Severe Accuracy: {high_severe_accuracy:.2f}%")
print(f"Overall Less Severe Accuracy: {less_severe_accuracy:.2f}%")

# Evaluate the model using true labels and predicted probabilities
y_true = np.array(true_labels)
y_pred = np.array(predicted_probs) <= 0.60
print("\nClassification Report:")
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing subsubfolder: dhdleg/train
# 1/1 [==============================] - 2s 2s/step
# Image: image5.jpg - Predicted Accuracy: 0.4538 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image21.jpg - Predicted Accuracy: 0.5275 - Severity: less severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image16.jpg - Predicted Accuracy: 0.3108 - Severity: less severe
# 1/1 [==============================] - 0s 140ms/step
# Image: image8.jpg - Predicted Accuracy: 0.5818 - Severity: less severe
# 1/1 [==============================] - 0s 144ms/step
# Image: image13.jpg - Predicted Accuracy: 0.4440 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image10.jpg - Predicted Accuracy: 0.4852 - Severity: less severe
# 1/1 [==============================] - 0s 224ms/step
# Image: image7.jpg - Predicted Accuracy: 0.4312 - Severity: less severe
# 1/1 [==============================] - 0s 263ms/step
# Image: image11.jpg - Predicted Accuracy: 0.6506 - Severity: high severe
# 1/1 [==============================] - 0s 242ms/step
# Image: image4.jpg - Predicted Accuracy: 0.4960 - Severity: less severe
# 1/1 [==============================] - 0s 223ms/step
# Image: image15.jpg - Predicted Accuracy: 0.4206 - Severity: less severe
# 1/1 [==============================] - 0s 229ms/step
# Image: image20.jpg - Predicted Accuracy: 0.4993 - Severity: less severe
# 1/1 [==============================] - 0s 226ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4376 - Severity: less severe
# 1/1 [==============================] - 0s 235ms/step
# Image: image14.jpg - Predicted Accuracy: 0.4552 - Severity: less severe
# 1/1 [==============================] - 0s 243ms/step
# Image: image12.jpg - Predicted Accuracy: 0.2675 - Severity: less severe
# 1/1 [==============================] - 0s 229ms/step
# Image: image6.jpg - Predicted Accuracy: 0.
- Severity: less severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image6.jpg - Predicted Accuracy: 0.3334 - Severity: less severe
# 1/1 [==============================] - 0s 122ms/step
# Image: image21.jpg - Predicted Accuracy: 0.3108 - Severity: less severe
# 1/1 [==============================] - 0s 126ms/step
# Image: image16.jpg - Predicted Accuracy: 0.6029 - Severity: high severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image10.jpg - Predicted Accuracy: 0.4462 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4538 - Severity: less severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image8.jpg - Predicted Accuracy: 0.5261 - Severity: less severe
# 1/1 [==============================] - 0s 123ms/step
# Image: image5.jpg - Predicted Accuracy: 0.5129 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image14.jpg - Predicted Accuracy: 0.6178 - Severity: high severe
# 1/1 [==============================] - 0s 149ms/step
# Image: image4.jpg - Predicted Accuracy: 0.4852 - Severity: less severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image11.jpg - Predicted Accuracy: 0.5275 - Severity: less severe
# 1/1 [==============================] - 0s 141ms/step
# Image: image9.jpg - Predicted Accuracy: 0.6230 - Severity: high severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image13.jpg - Predicted Accuracy: 0.4100 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image12.jpg - Predicted Accuracy: 0.5543 - Severity: less severe
# 1/1 [==============================] - 0s 150ms/step
# Image: image20.jpg - Predicted Accuracy: 0.5553 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image15.jpg - Predicted Accuracy: 0.6506 - Severity: high severe
# Processing subsubfolder: dhdpelvic/test
# 1/1 [==============================] - 0s 138ms/step
# Image: image19.jpg - Predicted Accuracy: 0.2598 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image17.jpg - Predicted Accuracy: 0.4820 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image2.jpg - Predicted Accuracy: 0.3911 - Severity: less severe
# 1/1 [==============================] - 0s 152ms/step
# Image: image3.jpg - Predicted Accuracy: 0.5111 - Severity: less severe
# Processing subsubfolder: llg/train
# 1/1 [==============================] - 0s 127ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3533 - Severity: less severe
# 1/1 [==============================] - 0s 126ms/step
# Image: image21.jpg - Predicted Accuracy: 0.3895 - Severity: less severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image14.jpg - Predicted Accuracy: 0.7099 - Severity: high severe
# 1/1 [==============================] - 0s 122ms/step
# Image: image15.jpg - Predicted Accuracy: 0.5351 - Severity: less severe
# 1/1 [==============================] - 0s 153ms/step
# Image: image11.jpg - Predicted Accuracy: 0.3877 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image5.jpg - Predicted Accuracy: 0.5550 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image10.jpg - Predicted Accuracy: 0.5438 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image7.jpg - Predicted Accuracy: 0.6506 - Severity: high severe
# 1/1 [==============================] - 0s 137ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4515 - Severity: less severe
# 1/1 [==============================] - 0s 146ms/step
# Image: image12.jpg - Predicted Accuracy: 0.5569 - Severity: less severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image8.jpg - Predicted Accuracy: 0.2966 - Severity: less severe
# 1/1 [==============================] - 0s 126ms/step
# Image: image20.jpg - Predicted Accuracy: 0.3066 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image18.jpg - Predicted Accuracy: 0.3296 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image9.jpg - Predicted Accuracy: 0.3911 - Severity: less severe
# 1/1 [==============================] - 0s 146ms/step
# Image: image16.jpg - Predicted Accuracy: 0.4785 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image13.jpg - Predicted Accuracy: 0.4255 - Severity: less severe
# Processing subsubfolder: llg/test
# 1/1 [==============================] - 0s 136ms/step
# Image: image19.jpg - Predicted Accuracy: 0.5167 - Severity: less severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image2.jpg - Predicted Accuracy: 0.5560 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image17.jpg - Predicted Accuracy: 0.5622 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image3.jpg - Predicted Accuracy: 0.4816 - Severity: less severe
#
# Overall High Severe Accuracy: 11.67%
# Overall Less Severe Accuracy: 88.33%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.88      0.94       120
#
#     accuracy                           0.88       120
#    macro avg       0.50      0.44      0.47       120
# weighted avg       1.00      0.88      0.94       120

# %%
# rcnn




from google.colab import drive
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import (
    Dense,
    GlobalAveragePooling2D,
    SimpleRNN,
    Dropout,
    Reshape,
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import os
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Define main data directory
neuro_dir = '/content/drive/MyDrive/Neuro'

# Load pre-trained InceptionV3 model without top layers
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)

# Reshape for RCNN
rcnn_input = Reshape((1, 128))(x)  # Reshape to (batch_size, timesteps, features)

# Add RNN layer
rnn_layer = SimpleRNN(64)(rcnn_input)

predictions_layer = Dense(1, activation='sigmoid')(rnn_layer)
model = Model(inputs=base_model.input, outputs=predictions_layer)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# List all main subfolders
main_subfolders = ['dhdleg', 'dhdhead', 'dhdgen', 'dhdpelvic','llg']

# Initialize counters for high severe and less severe images
high_severe_count = 0
less_severe_count = 0

# Lists to store true labels and predicted probabilities for evaluation
true_labels = []
predicted_probs = []

# Loop through main subfolders
for main_subfolder in main_subfolders:
    main_data_dir = os.path.join(neuro_dir, main_subfolder)

    subsubfolders = ['train', 'test']

    for subsubfolder in subsubfolders:
        data_dir = os.path.join(main_data_dir, subsubfolder)

        print(f"Processing subsubfolder: {main_subfolder}/{subsubfolder}")

        # List all image filenames in the subfolder
        image_filenames = [filename for filename in os.listdir(data_dir) if filename.lower().endswith(('.jpg', '.jpeg'))]

        if not image_filenames:
            print("No images found in the directory.")
            continue

        for image_filename in image_filenames:
            # Load the image, preprocess it, and make a prediction
            image_path = os.path.join(data_dir, image_filename)
            img = load_img(image_path, target_size=(224, 224))
            img_array = img_to_array(img)
            img_array = img_array / 255.0  # Normalize pixel values
            img_array = img_array.reshape((1,) + img_array.shape)

            true_label = 1  # Assuming all are high severe
            true_labels.append(true_label)

            prediction = model.predict(img_array)
            predicted_prob = prediction[0][0]
            predicted_probs.append(predicted_prob)

            if predicted_prob <= 0.40:
                less_severe_count += 1
            else:
                high_severe_count += 1

            severity = "less severe" if predicted_prob <= 0.80 else "high severe"

            print(f"Image: {image_filename} - Predicted Accuracy: {predicted_prob:.4f} - Severity: {severity}")

# Calculate overall accuracies
total_images = high_severe_count + less_severe_count
high_severe_accuracy = (high_severe_count / total_images) * 100 if total_images > 0 else 0
less_severe_accuracy = (less_severe_count / total_images) * 100 if total_images > 0 else 0

print(f"\nOverall High Severe Percentage: {high_severe_accuracy:.2f}%")
print(f"Overall Less Severe Percentage: {less_severe_accuracy:.2f}%")

# Evaluate the model using true labels and predicted probabilities
y_true = np.array(true_labels)
y_pred = np.array(predicted_probs) <= 0.40
print("\nClassification Report:")
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing subsubfolder: dhdleg/train
# 1/1 [==============================] - 2s 2s/step
# Image: image5.jpg - Predicted Accuracy: 0.2605 - Severity: less severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image21.jpg - Predicted Accuracy: 0.3393 - Severity: less severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image16.jpg - Predicted Accuracy: 0.2306 - Severity: less severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image8.jpg - Predicted Accuracy: 0.3605 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image13.jpg - Predicted Accuracy: 0.3636 - Severity: less severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image10.jpg - Predicted Accuracy: 0.2830 - Severity: less severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image7.jpg - Predicted Accuracy: 0.2051 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image11.jpg - Predicted Accuracy: 0.1706 - Severity: less severe
# 1/1 [==============================] - 0s 123ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3174 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image15.jpg - Predicted Accuracy: 0.2957 - Severity: less severe
# 1/1 [==============================] - 0s 126ms/step
# Image: image20.jpg - Predicted Accuracy: 0.4138 - Severity: less severe
# 1/1 [==============================] - 0s 137ms/step
# Image: image18.jpg - Predicted Accuracy: 0.1903 - Severity: less severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image14.jpg - Predicted Accuracy: 0.2312 - Severity: less severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image12.jpg - Predicted Accuracy: 0.3065 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image6.jpg - Predicted Accuracy: 0.5302 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image9.jpg - Predicted Accuracy: 0.1891 - Severity: less severe
# Processing subsubfolder: dhdleg/test
# 1/1 [==============================] - 0s 124ms/step
# Image: image3.jpg - Predicted Accuracy: 0.1290 - Severity: less severe
# 1/1 [==============================] - 0s 145ms/step
# Image: image17.jpg - Predicted Accuracy: 0.2845 - Severity: less severe
# 1/1 [==============================] - 0s 136ms/step
# Image: image2.jpg - Predicted Accuracy: 0.3634 - Severity: less severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image19.jpg - Predicted Accuracy: 0.4644 - Severity: less severe
# Processing subsubfolder: dhdhead/train
# 1/1 [==============================] - 0s 132ms/step
# Image: image20.jpg - Predicted Accuracy: 0.2845 - Severity: less severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image21.jpg - Predicted Accuracy: 0.2051 - Severity: less severe
# 1/1 [==============================] - 0s 140ms/step
# Image: image8.jpg - Predicted Accuracy: 0.2752 - Severity: less severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image13.jpg - Predicted Accuracy: 0.2830 - Severity: less severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image18.jpg - Predicted Accuracy: 0.2087 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image7.jpg - Predicted Accuracy: 0.3049 - Severity: less severe
# 1/1 [==============================] - 0s 122ms/step
# Image: image16.jpg - Predicted Accuracy: 0.3944 - Severity: less severe
# 1/1 [==============================] - 0s 122ms/step
# Image: image12.jpg - Predicted Accuracy: 0.1891 - Severity: less severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image6.jpg - Predicted Accuracy: 0.2770 - Severity: less severe
# 1/1 [==============================] - 0s 122ms/step
# Image: image9.jpg - Predicted Accuracy: 0.3402 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3393 - Severity: less severe
# 1/1 [==============================] - 0s 124ms/step
# Image: image11.jpg - Predicted Accuracy: 0.3288 - Severity: less severe
# 1/1 [==============================] - 0s 123ms/step
# Image: image10.jpg - Predicted Accuracy: 0.3634 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image14.jpg - Predicted Accuracy: 0.3636 - Severity: less severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image5.jpg - Predicted Accuracy: 0.2706 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image15.jpg - Predicted Accuracy: 0.3469 - Severity: less severe
# Processing subsubfolder: dhdhead/test
# 1/1 [==============================] - 0s 131ms/step
# Image: image19.jpg - Predicted Accuracy: 0.3065 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image2.jpg - Predicted Accuracy: 0.4015 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image17.jpg - Predicted Accuracy: 0.3594 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image3.jpg - Predicted Accuracy: 0.1408 - Severity: less severe
# Processing subsubfolder: dhdgen/train
# 1/1 [==============================] - 0s 124ms/step
# Image: image2.jpg - Predicted Accuracy: 0.2880 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image3.jpg - Predicted Accuracy: 0.2830 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image17.jpg - Predicted Accuracy: 0.2730 - Severity: less severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image19.jpg - Predicted Accuracy: 0.3288 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image:
- Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image12.jpg - Predicted Accuracy: 0.4036 - Severity: less severe
# 1/1 [==============================] - 0s 141ms/step
# Image: image8.jpg - Predicted Accuracy: 0.4340 - Severity: less severe
# 1/1 [==============================] - 0s 125ms/step
# Image: image20.jpg - Predicted Accuracy: 0.2605 - Severity: less severe
# 1/1 [==============================] - 0s 189ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4475 - Severity: less severe
# 1/1 [==============================] - 0s 224ms/step
# Image: image9.jpg - Predicted Accuracy: 0.3634 - Severity: less severe
# 1/1 [==============================] - 0s 226ms/step
# Image: image16.jpg - Predicted Accuracy: 0.2876 - Severity: less severe
# 1/1 [==============================] - 0s 237ms/step
# Image: image13.jpg - Predicted Accuracy: 0.4132 - Severity: less severe
# Processing subsubfolder: llg/test
# 1/1 [==============================] - 0s 220ms/step
# Image: image19.jpg - Predicted Accuracy: 0.3082 - Severity: less severe
# 1/1 [==============================] - 0s 232ms/step
# Image: image2.jpg - Predicted Accuracy: 0.3666 - Severity: less severe
# 1/1 [==============================] - 0s 233ms/step
# Image: image17.jpg - Predicted Accuracy: 0.3012 - Severity: less severe
# 1/1 [==============================] - 0s 246ms/step
# Image: image3.jpg - Predicted Accuracy: 0.3314 - Severity: less severe
#
# Overall High Severe Percentage: 9.17%
# Overall Less Severe Percentage: 90.83%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.91      0.95       120
#
#     accuracy                           0.91       120
#    macro avg       0.50      0.45      0.48       120
# weighted avg       1.00      0.91      0.95       120

# %%
#random forest




from google.colab import drive
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import (
    Dense,
    GlobalAveragePooling2D,
    SimpleRNN,
    Dropout,
    Reshape,
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
import os
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Define main data directory
neuro_dir = '/content/drive/MyDrive/Neuro'

# Load pre-trained InceptionV3 model without top layers
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)

# Reshape for RCNN
rcnn_input = Reshape((1, 128))(x)  # Reshape to (batch_size, timesteps, features)

# Add RNN layer
rnn_layer = SimpleRNN(64)(rcnn_input)

predictions_layer = Dense(1, activation='sigmoid')(rnn_layer)
model = Model(inputs=base_model.input, outputs=predictions_layer)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# List all main subfolders
main_subfolders = ['dhdleg', 'dhdhead', 'dhdgen', 'dhdpelvic', 'llg']

# Initialize counters for high severe and less severe images
high_severe_count = 0
less_severe_count = 0

# Lists to store true labels and predicted probabilities for evaluation
true_labels = []
predicted_probs = []

# Lists to store features and labels for Random Forest training
high_severe_features = []
high_severe_labels = []
less_severe_features = []
less_severe_labels = []

# Initialize Random Forest classifiers
rf_high_severe = RandomForestClassifier(n_estimators=100)
rf_less_severe = RandomForestClassifier(n_estimators=100)

# Loop through main subfolders
for main_subfolder in main_subfolders:
    main_data_dir = os.path.join(neuro_dir, main_subfolder)

    subsubfolders = ['train', 'test']

    for subsubfolder in subsubfolders:
        data_dir = os.path.join(main_data_dir, subsubfolder)

        print(f"Processing subsubfolder: {main_subfolder}/{subsubfolder}")

        # List all image filenames in the subfolder
        image_filenames = [filename for filename in os.listdir(data_dir) if filename.lower().endswith(('.jpg', '.jpeg'))]

        if not image_filenames:
            print("No images found in the directory.")
            continue

        for image_filename in image_filenames:
            # Load the image, preprocess it, and make a prediction
            image_path = os.path.join(data_dir, image_filename)
            img = load_img(image_path, target_size=(224, 224))
            img_array = img_to_array(img)
            img_array = img_array / 255.0  # Normalize pixel values
            img_array = img_array.reshape((1,) + img_array.shape)

            true_label = 1  # Assuming all are high severe
            true_labels.append(true_label)

            prediction = model.predict(img_array)
            predicted_prob = prediction[0][0]
            predicted_probs.append(predicted_prob)

            if predicted_prob <= 0.40:
                less_severe_count += 1
                less_severe_features.append(img_array.flatten())
                less_severe_labels.append(true_label)
            else:
                high_severe_count += 1
                high_severe_features.append(img_array.flatten())
                high_severe_labels.append(true_label)

            severity = "less severe" if predicted_prob <= 0.40 else "high severe"

            print(f"Image: {image_filename} - Predicted Accuracy: {predicted_prob:.4f} - Severity: {severity}")

# Train Random Forest classifiers if there are enough samples
if len(high_severe_features) >= 100:
    rf_high_severe.fit(np.array(high_severe_features), np.array(high_severe_labels))
if len(less_severe_features) >= 100:
    rf_less_severe.fit(np.array(less_severe_features), np.array(less_severe_labels))

# Calculate overall accuracies
total_images = high_severe_count + less_severe_count
high_severe_accuracy = (high_severe_count / total_images) * 100 if total_images > 0 else 0
less_severe_accuracy = (less_severe_count / total_images) * 100 if total_images > 0 else 0

print(f"\nOverall High Severe Accuracy: {high_severe_accuracy:.2f}%")
print(f"Overall Less Severe Accuracy: {less_severe_accuracy:.2f}%")

# Evaluate the model using true labels and predicted probabilities
y_true = np.array(true_labels)
y_pred = np.array(predicted_probs) <= 0.40
print("\nClassification Report:")
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing subsubfolder: dhdleg/train
# 1/1 [==============================] - 2s 2s/step
# Image: image5.jpg - Predicted Accuracy: 0.4426 - Severity: high severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image21.jpg - Predicted Accuracy: 0.3298 - Severity: less severe
# 1/1 [==============================] - 0s 144ms/step
# Image: image16.jpg - Predicted Accuracy: 0.5058 - Severity: high severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image8.jpg - Predicted Accuracy: 0.5658 - Severity: high severe
# 1/1 [==============================] - 0s 129ms/step
# Image: image13.jpg - Predicted Accuracy: 0.5557 - Severity: high severe
# 1/1 [==============================] - 0s 140ms/step
# Image: image10.jpg - Predicted Accuracy: 0.3031 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image7.jpg - Predicted Accuracy: 0.3757 - Severity: less severe
# 1/1 [==============================] - 0s 136ms/step
# Image: image11.jpg - Predicted Accuracy: 0.6147 - Severity: high severe
# 1/1 [==============================] - 0s 136ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3488 - Severity: less severe
# 1/1 [==============================] - 0s 146ms/step
# Image: image15.jpg - Predicted Accuracy: 0.6156 - Severity: high severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image20.jpg - Predicted Accuracy: 0.3902 - Severity: less severe
# 1/1 [==============================] - 0s 136ms/step
# Image: image18.jpg - Predicted Accuracy: 0.3955 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image14.jpg - Predicted Accuracy: 0.3747 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image12.jpg - Predicted Accuracy: 0.6194 - Severity: high severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4743 - Severity: high severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image9.jpg - Predicted Accuracy: 0.6126 - Severity: high severe
# Processing subsubfolder: dhdleg/test
# 1/1 [==============================] - 0s 136ms/step
# Image: image3.jpg - Predicted Accuracy: 0.5287 - Severity: high severe
# 1/1 [==============================] - 0s 146ms/step
# Image: image17.jpg - Predicted Accuracy: 0.4647 - Severity: high severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image2.jpg - Predicted Accuracy: 0.3564 - Severity: less severe
# 1/1 [==============================] - 0s 145ms/step
# Image: image19.jpg - Predicted Accuracy: 0.2260 - Severity: less severe
# Processing subsubfolder: dhdhead/train
# 1/1 [==============================] - 0s 134ms/step
# Image: image20.jpg - Predicted Accuracy: 0.4647 - Severity: high severe
# 1/1 [==============================] - 0s 231ms/step
# Image: image21.jpg - Predicted Accuracy: 0.3757 - Severity: less severe
# 1/1 [==============================] - 0s 253ms/step
# Image: image8.jpg - Predicted Accuracy: 0.3274 - Severity: less severe
# 1/1 [==============================] - 0s 248ms/step
# Image: image13.jpg - Predicted Accuracy: 0.3031 - Severity: less severe
# 1/1 [==============================] - 0s 249ms/step
# Image: image18.jpg - Predicted Accuracy: 0.5254 - Severity: high severe
# 1/1 [==============================] - 0s 249ms/step
# Image: image7.jpg - Predicted Accuracy: 0.3487 - Severity: less severe
# 1/1 [==============================] - 0s 247ms/step
# Image: image16.jpg - Predicted Accuracy: 0.5519 - Severity: high severe
# 1/1 [==============================] - 0s 240ms/step
# Image: image12.jpg - Predicted Accuracy: 0.6126 - Severity: high severe
# 1/1 [==============================] - 0s 247ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4817 - Severity: high severe
# 1/1 [==============================] - 0s 242ms/step
# Image: image9.jpg - Predicted Accuracy: 0.3120 - Severity: less severe
# 1/1 [==============================] - 0s 241ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3298 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image11.jpg - Predicted Accuracy: 0.4096 - Severity: high severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image10.jpg - Predicted Accuracy: 0.3564 - Severity: less severe
# 1/1 [==============================] - 0s 151ms/step
# Image: image14.jpg - Predicted Accuracy: 0.5557 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image5.jpg - Predicted Accuracy: 0.4398 - Severity: high severe
# 1/1 [==============================] - 0s 144ms/step
# Image: image15.jpg - Predicted Accuracy: 0.5165 - Severity: high severe
# Processing subsubfolder: dhdhead/test
# 1/1 [==============================] - 0s 133ms/step
# Image: image19.jpg - Predicted Accuracy: 0.6194 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image2.jpg - Predicted Accuracy: 0.2145 - Severity: less severe
# 1/1 [==============================] - 0s 144ms/step
# Image: image17.jpg - Predicted Accuracy: 0.2579 - Severity: less severe
# 1/1 [==============================] - 0s 142ms/step
# Image: image3.jpg - Predicted Accuracy: 0.5478 - Severity: high severe
# Processing subsubfolder: dhdgen/train
# 1/1 [==============================] - 0s 138ms/step
# Image: image2.jpg - Predicted Accuracy: 0.4079 - Severity: high severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image3.jpg - Predicted Accuracy: 0.3031 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image17.jpg - Predicted Accuracy: 0.3796 - Severity: less severe
# 1/1 [==============================] - 0s 145ms/step
# Image: image19.jpg - Predicted Accuracy: 0.4096 - Severity: high severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image12.jpg - Predicted Accuracy: 0.4674 - Severity: high severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image15.jpg - Predicted Accuracy: 0.4578 - Severity: high severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image8.jpg - Predicted Accuracy: 0.3564 - Severity: less severe
# 1/1 [==============================] - 0s 140ms/step
# Image: image18.jpg - Predicted Accuracy: 0.3757 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image16.jpg - Predicted Accuracy: 0.3223 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image21.jpg - Predicted Accuracy: 0.6126 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image11.jpg - Predicted Accuracy: 0.5658 - Severity: high severe
# 1/1 [==============================] - 0s 123ms/step
# Image: image10.jpg - Predicted Accuracy: 0.4426 - Severity: high severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image20.jpg - Predicted Accuracy: 0.3816 - Severity: less severe
# 1/1 [==============================] - 0s 142ms/step
# Image: image5.jpg - Predicted Accuracy: 0.2579 - Severity: less severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image7.jpg - Predicted Accuracy: 0.3682 - Severity: less severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image14.jpg - Predicted Accuracy: 0.3796 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image4.jpg - Predicted Accuracy: 0.2939 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image9.jpg - Predicted Accuracy: 0.1942 - Severity: less severe
# 1/1 [==============================] - 0s 146ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4079 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image13.jpg - Predicted Accuracy: 0.3060 - Severity: less severe
# Processing subsubfolder: dhdgen/test
# 1/1 [==============================] - 0s 135ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3682 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image5.jpg - Predicted Accuracy: 0.3488 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image6.jpg - Predicted Accuracy: 0.2939 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image7.jpg - Predicted Accuracy: 0.2579 - Severity: less severe
# 1/1 [==============================] - 0s 136ms/step
# Image: image8.jpg - Predicted Accuracy: 0.3564 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image9.jpg - Predicted Accuracy: 0.5658 - Severity: high severe
# 1/1 [==============================] - 0s 137ms/step
# Image: image10.jpg - Predicted Accuracy: 0.3223 - Severity: less severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image11.jpg - Predicted Accuracy: 0.2027 - Severity: less severe
# 1/1 [==============================] - 0s 150ms/step
# Image: image12.jpg - Predicted Accuracy: 0.3147 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image13.jpg - Predicted Accuracy: 0.4578 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image14.jpg - Predicted Accuracy: 0.4674 - Severity: high severe
# 1/1 [==============================] - 0s 137ms/step
# Image: image15.jpg - Predicted Accuracy: 0.4426 - Severity: high severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image16.jpg - Predicted Accuracy: 0.3060 - Severity: less severe
# 1/1 [==============================] - 0s 160ms/step
# Image: image18.jpg - Predicted Accuracy: 0.5295 - Severity: high severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image20.jpg - Predicted Accuracy: 0.3816 - Severity: less severe
# 1/1 [==============================] - 0s 135ms/step
# Image: image21.jpg - Predicted Accuracy: 0.3290 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image3.jpg - Predicted Accuracy: 0.3488 - Severity: less severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image2.jpg - Predicted Accuracy: 0.3031 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image17.jpg - Predicted Accuracy: 0.4096 - Severity: high severe
# 1/1 [==============================] - 0s 165ms/step
# Image: image19.jpg - Predicted Accuracy: 0.3290 - Severity: less severe
# Processing subsubfolder: dhdpelvic/train
# 1/1 [==============================] - 0s 230ms/step
# Image: image7.jpg - Predicted Accuracy: 0.3796 - Severity: less severe
# 1/1 [==============================] - 0s 241ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4079 - Severity: high severe
# 1/1 [==============================] - 0s 247ms/step
# Image: image21.jpg - Predicted Accuracy: 0.5058 - Severity: high severe
# 1/1 [==============================] - 0s 234ms/step
# Image: image16.jpg - Predicted Accuracy: 0.5165 - Severity: high severe
# 1/1 [==============================] - 0s 233ms/step
# Image: image10.jpg - Predicted Accuracy: 0.4096 - Severity: high severe
# 1/1 [==============================] - 0s 240ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4426 - Severity: high severe
# 1/1 [==============================] - 0s 238ms/step
# Image: image8.jpg - Predicted Accuracy: 0.4674 - Severity: high severe
# 1/1 [==============================] - 0s 243ms/step
# Image: image5.jpg - Predicted Accuracy: 0.3487 - Severity: less severe
# 1/1 [==============================] - 0s 240ms/step
# Image: image14.jpg - Predicted Accuracy: 0.5219 - Severity: high severe
# 1/1 [==============================] - 0s 230ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3031 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image11.jpg - Predicted Accuracy: 0.3298 - Severity: less severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image9.jpg - Predicted Accuracy: 0.2954 - Severity: less severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image13.jpg - Predicted Accuracy: 0.4279 - Severity: high severe
# 1/1 [==============================] - 0s 128ms/step
# Image: image12.jpg - Predicted Accuracy: 0.6126 - Severity: high severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image20.jpg - Predicted Accuracy: 0.3682 - Severity: less severe
# 1/1 [==============================] - 0s 147ms/step
# Image: image15.jpg - Predicted Accuracy: 0.6147 - Severity: high severe
# Processing subsubfolder: dhdpelvic/test
# 1/1 [==============================] - 0s 135ms/step
# Image: image19.jpg - Predicted Accuracy: 0.6157 - Severity: high severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image17.jpg - Predicted Accuracy: 0.2706 - Severity: less severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image2.jpg - Predicted Accuracy: 0.3564 - Severity: less severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image3.jpg - Predicted Accuracy: 0.4647 - Severity: high severe
# Processing subsubfolder: llg/train
# 1/1 [==============================] - 0s 149ms/step
# Image: image4.jpg - Predicted Accuracy: 0.3290 - Severity: less severe
# 1/1 [==============================] - 0s 141ms/step
# Image: image21.jpg - Predicted Accuracy: 0.1709 - Severity: less severe
# 1/1 [==============================] - 0s 138ms/step
# Image: image14.jpg - Predicted Accuracy: 0.4742 - Severity: high severe
# 1/1 [==============================] - 0s 133ms/step
# Image: image15.jpg - Predicted Accuracy: 0.4122 - Severity: high severe
# 1/1 [==============================] - 0s 137ms/step
# Image: image11.jpg - Predicted Accuracy: 0.3413 - Severity: less severe
# 1/1 [==============================] - 0s 146ms/step
# Image: image5.jpg - Predicted Accuracy: 0.5198 - Severity: high severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image10.jpg - Predicted Accuracy: 0.5934 - Severity: high severe
# 1/1 [==============================] - 0s 131ms/step
# Image: image7.jpg - Predicted Accuracy: 0.6147 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image6.jpg - Predicted Accuracy: 0.4922 - Severity: high severe
# 1/1 [==============================] - 0s 140ms/step
# Image: image12.jpg - Predicted Accuracy: 0.2323 - Severity: less severe
# 1/1 [==============================] - 0s 144ms/step
# Image: image8.jpg - Predicted Accuracy: 0.3213 - Severity: less severe
# 1/1 [==============================] - 0s 139ms/step
# Image: image20.jpg - Predicted Accuracy: 0.4093 - Severity: high severe
# 1/1 [==============================] - 0s 130ms/step
# Image: image18.jpg - Predicted Accuracy: 0.4314 - Severity: high severe
# 1/1 [==============================] - 0s 132ms/step
# Image: image9.jpg - Predicted Accuracy: 0.3564 - Severity: less severe
# 1/1 [==============================] - 0s 148ms/step
# Image: image16.jpg - Predicted Accuracy: 0.3771 - Severity: less severe
# 1/1 [==============================] - 0s 142ms/step
# Image: image13.jpg - Predicted Accuracy: 0.3571 - Severity: less severe
# Processing subsubfolder: llg/test
# 1/1 [==============================] - 0s 130ms/step
# Image: image19.jpg - Predicted Accuracy: 0.5032 - Severity: high severe
# 1/1 [==============================] - 0s 127ms/step
# Image: image2.jpg - Predicted Accuracy: 0.4782 - Severity: high severe
# 1/1 [==============================] - 0s 134ms/step
# Image: image17.jpg - Predicted Accuracy: 0.3452 - Severity: less severe
# 1/1 [==============================] - 0s 142ms/step
# Image: image3.jpg - Predicted Accuracy: 0.3089 - Severity: less severe
#
# Overall High Severe Accuracy: 48.33%
# Overall Less Severe Accuracy: 51.67%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.52      0.68       120
#
#     accuracy                           0.52       120
#    macro avg       0.50      0.26      0.34       120
# weighted avg       1.00      0.52      0.68       120
